# %%
### Scenerio based question and logical question

# %%
lst = [10,20,30,40,40,50,60,70,80]

print(lst)
# Out:
# [10, 20, 30, 40, 40, 50, 60, 70, 80]

# %%
a = set(lst)
print(a)
# Out:
# {70, 40, 10, 80, 50, 20, 60, 30}

# %%
c = set(lst)
b = list(c)
print(b)
# Out:
# [70, 40, 10, 80, 50, 20, 60, 30]

# %%
uni = [] 

for i in lst:
    if i not in uni:
        uni.append(i)
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
num = 80

if num % 2 ==0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
odd = []

for i in uni:
    if i % 2 != 0:   #not equal not use 
        odd.append(i)
print(odd)
# Out:
# []

# %%
odd = []

for i in uni:
    if i % 2 == 1:
        odd.append(i)
print(odd)
# Out:
# []

# %%
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
# [10,20,30,40,50,60]

a = []

for i in uni:
    if i == 70:    # not to use for loop
        break
    else:              
        a.append(i)
print(a)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
print(uni[0:6])          # not to use slicing
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
# [10,20,30,40,50,60]

uni.pop()
# uni.pop()    # not to use pop method
print(uni)
# Out:
# [10, 20, 30, 40]

# %%
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
del uni[6:8]     # del not to use
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
uni.remove(70)    # not to use remove method
uni.remove(80)

# %%
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
print(" ".join(map(str,uni[:6])))  # not valid
# Out:
# 10 20 30 40 50 60

# %%
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
# [10,20,30,40,50,60]

i = 0

while i < len(uni):
    if uni[i] > 60: 
        uni.remove(uni[i])   # Not to use remove method in while loop
    else:
        i += 1
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
print(uni)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
# [10,20,30,40,50,60]
# not use list methods

i = 0
a =[]

while i < len(uni):
    if uni[i] > 60:
        break
    else:
        a.append(uni[i])
    i += 1
print(a)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
i = 0
a =[]

while i < len(uni):
    if uni[i] == 70:
        break
    else:
        a.append(uni[i])
    i += 1
print(a)
# Out:
# [10, 20, 30, 40, 50, 60]
