# %%
print('Hi')
# Out:
# Hi

# %%
print('55')
# Out:
# 55

# %%
print("10-12-2025")
# Out:
# 10-12-2025

# %% [markdown]
# ## , Seperator
# ## ( open parenthesis and ) close parenthesis
#
# ## sep - keyword or argument

# %%
print("apple","mango","banana","kiwi","ornage",sep="++")
# Out:
# apple++mango++banana++kiwi++ornage

# %%
print("hello","hello",end=",Good morning ")
print("Bhavani")
print("lein")
# Out:
# hello hello,Good morning Bhavani
# lein

# %%
print("bhavani","lein","Riswan","Bhavadharani","vignesh",sep="..",end=", Hi students ")
print("welcome")
# Out:
# bhavani..lein..Riswan..Bhavadharani..vignesh, Hi students welcome

# %%
# hi..hi..hi
print("hi","hi",sep="..",end="..hi")
# Out:
# hi..hi..hi

# %%
print("hi","hi",sep="..",end="..")
print("hi")
# Out:
# hi..hi..hi

# %%
print("hi","hi","hi",sep="..")
# Out:
# hi..hi..hi

# %%
print("hi","hi",sep="..hi..")
# Out:
# hi..hi..hi

# %%
print(6*2)
# Out:
# 12

# %%
# print("apple","mango","banana","kiwi","ornage",sep="++")
# Out:
# apple++mango++banana++kiwi++ornage
# '\nprint("hello","hello",end=",Good morning ")\nprint("Bhavani")\nprint("lein")\n'

# %%
print('""')
# Out:
# ""

# %%
print("''")
# Out:
# ''

# %%
print("""")
# Out:
#   Cell In[61], line 1
#     print("""")
#           ^
# SyntaxError: incomplete input

# %% [markdown]
# #### title

# %%
print(8-5)
# Out:
# 3

# %% [markdown]
# ## Variables are containers for storing data values.

# %%
a = 5    # a is a variable name or container or identifier  and  5 is value and = is a assingment operator is used to assing the value 
          # to a variable
print(a)
# Out:
# 5

# %%
b = 10
print(b)
# Out:
# 10

# %%
c = "oil"
print(c)
# Out:
# oil

# %% [markdown]
# # Rules of variables or identifiers

# %% [markdown]
# ## 1. variables cannot be start with a number
# ## 2. variables cannot be start with a python keyword
# ## 3. variables must be in case sensitive
# ## 4. vaiables must be start wiht a alphabet or underscore

# %%
5 = 5 # rule 1
# Out:
#   Cell In[72], line 1
#     5 = 5
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
True = 5 # rule 2
# Out:
#   Cell In[77], line 1
#     True = 5 # rule 2
#     ^
# SyntaxError: cannot assign to True

# %%
smallNum = 1 # rule 3
print(smallNum)
# Out:
# 1

# %%
_ = 5 # rule 4
print(_)
# Out:
# 5

# %%
a = 8    #rule 4
print(a)
# Out:
# 8

# %%
a5 = 0
print(a5)
# Out:
# 0

# %%
b-= 6
print(b-)
# Out:
#   Cell In[89], line 2
#     print(b-)
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Print

# %%
print("Hello")
# Out:
# Hello

# %%
print(23)
# Out:
# 23

# %%
print(hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(hello)
#
# NameError: name 'hello' is not defined

# %%
print("25")
# Out:
# 25

# %% [markdown]
# ### End

# %%
print('apple',"strawberry",'kiwi','avacado','mango',end="+")  # end and sep is a arguments | end as default /n - new line 
print("fruits")
print('apple',"strawberry",'kiwi','avacado','mango',end=" This is all are ")
print('fru')
# Out:
# apple strawberry kiwi avacado mango+fruits
# apple strawberry kiwi avacado mango This is all are fru

# %% [markdown]
# ## Sep

# %%
print('apple',"strawberry",'kiwi','avacado','mango',sep=" ")    # comma - seperator
# Out:
# apple  strawberry  kiwi  avacado  mango

# %% [markdown]
# ## Task

# %%
### good morning python

print("good morning",end=" ")
print("python")
# Out:
# good morning python

# %%
# hello..hello..hello

print("hello","hello",end="..",sep="..")
print("hello")
# Out:
# hello..hello..hello

# %%
print(7+2)  # hot encoding
# Out:
# 9

# %%
print(5*2)
# Out:
# 10

# %% [markdown]
# ## Variables

# %%
a = 5
print(a)
# Out:
# 5

# %%
b = "python"
print(b)
# Out:
# python

# %% [markdown]
# ## Rules of variables or containers or identifiers

# %% [markdown]
# ## 1. variables cannot be start with a number
# ## 2. variables cannot be start with a python keyword
# ## 3. variables must be in case sensitive
# ## 4. vaiables must be start wiht a alphabet or underscore

# %%
1ab = 5
print(1ab)  # X
# Out:
#   Cell In[40], line 1
#     1ab = 5
#     ^
# SyntaxError: invalid decimal literal

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
for = 5
print(for)  # X
# Out:
#   Cell In[45], line 1
#     for = 5
#         ^
# SyntaxError: invalid syntax

# %%
NameofUser = "Durga"
print(NameofUser)  # C
# Out:
# Durga

# %%
a1 = 10
print(a1) # C
# Out:
# 10

# %%
_ = 8
print(_) # C
# Out:
# 8

# %% [markdown]
# ## Data types

# %% [markdown]
# ## simple data types - one cat

# %% [markdown]
# ### integer - int - whole number   -1,0,1,2
# ### float  - float - decimal point - 0.45,0.9,1.3
# ### string - str  - alphabets - a ,b Name ,Number
# ### boolean - bool - True or 1 and False or 0

# %% [markdown]
# ## Complex data type or data structure

# %% [markdown]
# ### list - lst - collection of items - [] - [1,2,"name"]
# ### tuples - tup - collection of items - () - (1,2,"name")
# ### set - set - collection of items - {} - {1,2,"name"}
# ### Dictionary - dict - key and value pairs - {} - {"name":"Python","year": 1991}

# %% [markdown]
# ### Type Inferred - python itself assume or identify the data type

# %%
num = 5
print(num)
print(type(num))
# Out:
# 5
# <class 'int'>

# %%
flt = 5.0
print(flt)
print(type(flt))
# Out:
# 5.0
# <class 'float'>

# %%
fruit = "apple"
print(fruit)
print(type(fruit))
# Out:
# apple
# <class 'str'>

# %%
status = "Y"
print(status)
print(type(status))
# Out:
# Y
# <class 'str'>

# %%
b = "10"
print(b)
print(type(b))
# Out:
# 10
# <class 'str'>

# %%
active = True
print(active)
print(type(active))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# ### Dynamically typed or typing

# %%
num = "10"
print(num)
print(type(num))
# Out:
# 10
# <class 'str'>

# %%
print(num)
# Out:
# 10

# %%
print(num)
# Out:
# 10

# %%
print(num)
# Out:
# 10

# %% [markdown]
# ## Operators

# %% [markdown]
# ### Arithmetic operators
# ### Relational or comparision operator
# ### Logical operator
# ### Membership operator
# ### bitwise operator (optional)
# ### Assignment operator
# ### identity operator
# ### ternary or conditional operator

# %% [markdown]
# ### Arithmetic operator

# %%
# +,-,*,/,%,//,**

# %%
a = 10
b = 5
print(a,b)
# Out:
# 10 5

# %%
print(a+b)  # 10 + 5
# Out:
# 15

# %%
print(a-b)
# Out:
# 5

# %%
print(a*b)
# Out:
# 50

# %%
print(a/b)
# Out:
# 2.0

# %%
print(a//b)  # floor division
# Out:
# 2

# %%
print(a%b) #  modulus return a remainder value
# Out:
# 0

# %%
c = 3
d = 2
print(c/d)
print(c//d)  # floor division
# Out:
# 1.5
# 1

# %%
print(c**d)               2
                       # 3 exponent
# Out:
# 9

# %% [markdown]
# ### Relational or Comparision operator

# %%
## <,>,<=,>=,==,!=

a = 10
b = 5
print(a,b)
# Out:
# 10 5

# %%
print(a<b) # 10 < 5
# Out:
# False

# %%
print(a>b)
# Out:
# True

# %%
print(a == b)   # = is a assigment and == is a comparision
# Out:
# False

# %%
print(a<=b)
# Out:
# True

# %%
print(a>=b)
# Out:
# True

# %%
print(a!=b)
# Out:
# True

# %%
c = "gopiS"
d = "gopiS"

print(c,d)     # Ascii - american standard code for information interchange
# Out:
# gopiS gopiS

# %%
print(ord("g"))
print(ord("n"))
# Out:
# 103
# 110

# %%
print(chr(103))
# Out:
# g

# %%
print(c<d)   # g<n - 103> 110 =  F
# Out:
# True

# %%
print(ord("o"))
print(ord("a"))   # o<a 111> 97 =T
# Out:
# 111
# 97

# %%
print(ord("p"))
print(ord("t"))  # p < t  112>116 = F
# Out:
# 112
# 116

# %%
print(ord("i"))
print(ord("h"))   # 105>104 = T
# Out:
# 105
# 104

# %%
print(ord("S"))
print(ord("s"))  # 83>115 = F
# Out:
# 83
# 115

# %%
print(c>d)
# Out:
# False

# %%
print(c==d)
# Out:
# True

# %%
print(c<=d)
# Out:
# True

# %%
p = "Python"
q = "nohtyp"

print(p,q)    # lesser than
# Out:
# Python nohtyp

# %%
print(ord("P"))
print(ord("n"))   # 80 < 110 = T
# Out:
# 80
# 110

# %%
print(ord("y"))
print(ord("o"))  # 121<111= F
# Out:
# 121
# 111

# %%
print(ord("t"))
print(ord("h"))  # 116 < 104 = F
# Out:
# 116
# 104

# %%
print(ord("h"))
print(ord("t"))  # 104< 116 = T
# Out:
# 104
# 116

# %%
p = "Python"
q = "nohtyp"

print(p,q)
# Out:
# Python nohtyp

# %%
print(ord("o"))
print(ord("y"))  # 111<121 = T
# Out:
# 111
# 121

# %%
print(ord("n"))
print(ord("p"))  # 110 < 112 = T
# Out:
# 110
# 112

# %%
print(p<q)
# Out:
# True

# %%
print(p>q)
# Out:
# False

# %%
e = "Python"  # 80 121 116 104 111 110  
f = "nohtn"   # 110 111 104 116 110     # 111>110 T
              #  T  F   F  T  f- lesser than
print(e,f)   #  F   T   T  F  t- greater than
# Out:
# Python noht

# %%
print(e<f)
# Out:
# True

# %%
print(e>f)
# Out:
# False

# %%
a = "Print" 
b = "pRINT"
print(a,b)
# Out:
# Print pRINT

# %%
print(a<b)
# Out:
# True

# %%
print(ord("P"))
print(ord("p"))  # 80 < 112 = T
# Out:
# 80
# 112

# %%
print(ord("r")) 
print(ord("R")) # 114<82 = F
print(ord("i"))
print(ord("I"))  # 105<73 = F
print(ord("n"))
print(ord("N"))  # 110<78 = F
print(ord("t"))
print(ord("T"))   # 116 < 84 = F
# Out:
# 114
# 82
# 105
# 73
# 110
# 78
# 116
# 84

# %%
a = "sivas"
b = "siva"
print(a,b)
# Out:
# sivas siva

# %%
print(ord("S")) 
print(ord("s"))  # 83<115 = T
print(ord("a"))    # 83<97 = T
# Out:
# 83
# 115
# 97

# %%
print(a<b)
# Out:
# False

# %%
print(a==b)
# Out:
# False

# %%
print(a>b)
# Out:
# True

# %%
h = "helloWorldI"
x = "helloWorldi"
print(h,x)
# Out:
# helloWorldI helloWorldi

# %%
print(h<x)
# Out:
# True

# %%
print(ord("i"))
print(ord("d")) #72<104 = T  # 105>100 = T
# Out:
# 105
# 100

# %%
print(h>x)
# Out:
# False

# %%
print(h==x)
# Out:
# False

# %%
m = "Mango"
n = "apple"  # 77 <97 = T 97<112 =T  110<112 = T  103 <108= T

print(m,n)
# Out:
# Mango apple

# %%
print(m<n)
# Out:
# True

# %%
print(m>n)
# Out:
# False

# %%
a= "shar"
b= "lath" 

print(a,b)  #115 < 108 =F  104<97 =F  97 < 116 =T  114<104 =F    - lesser than
            #115 > 108 =T  104>97 =F  97 > 116 =T  114>104 =T    - greater than
# Out:
# shar lath

# %%
print(a<b)
# Out:
# False

# %%
print(a>b)
# Out:
# True

# %% [markdown]
# ## Logical Operator

# %%
### And,or,not

# %%
statement1 = "python"
statement2 = "python"

print(statement1 == statement2)
# Out:
# True

# %%
print(statement1 and statement2)
# Out:
# python

# %%
if statement1=="pytho" and statement2=="python":
    print("both statement are correct")
else:
    print("both statement are not correct")
# Out:
# both statement are not correct

# %%
if statement1=="pytho" or statement2=="pytho":
    print("both statement are correct")
else:
    print("both statement are not correct")
# Out:
# both statement are not correct

# %%
age = 18
vote_id = False
 
      # T       # F
   # 19 >= 18   # T
if age>=18 and vote_id:
    print("you can vote!")
else:
    print("you cannot vote!")
# Out:
# you cannot vote!

# %%
age = 19
vote_id = False

  #  T          F
if age>=18 or vote_id:
    print("you can vote!")
else:
    print("you cannot vote!")
# Out:
# you can vote!

# %%
print(statement1,statement2)
# Out:
# python python

# %%
print(not False)
# Out:
# True

# %%
print(not statement1=="python")  # Not T
# Out:
# False

# %%
print(not statement1=="pytho")  # not F
# Out:
# True

# %% [markdown]
# ### Agumented assignment operator or asssignment operator

# %%
a = 5  # = is a assignment operator and == comparision operator

# %% [markdown]
# #### combination of both arithmetic and assigment operator

# %%
# +,-,*,/,//,%,**

# %%
a = 10
b = 5

print(a,b)
# Out:
# 10 5

# %%
a = a+2   # 10+2 = 12

# %%
a += 2   # a = 10+2 = 12#
print(a)
# Out:
# 12

# %%
a -= 2
print(a)
# Out:
# 8

# %%
a *= 2
print(a)
# Out:
# 20

# %% [markdown]
# ### Membership operator

# %%
# in , not in

# %%
fruits = ("apple","strawberry","jack fruit","kiwi","orange","guva","papaya")

print(fruits)
# Out:
# ('apple', 'strawberry', 'jack fruit', 'kiwi', 'orange', 'guva', 'papaya')

# %%
print("papaya" in fruits)   # T
# Out:
# True

# %%
print("pine apple" in fruits)   # F
# Out:
# False

# %%
print("pine apple" not in fruits)  # T
# Out:
# True

# %%
print("papaya" not in fruits)  #F
# Out:
# False

# %%
print(not True)
# Out:
# False

# %%
print(not False)
# Out:
# True

# %% [markdown]
# ### Identity operator

# %%
## is and is not

# %%
a = 300
b = 5
c = 300
d = c
print(a,b,c,d)
# Out:
# 300 5 300 300

# %%
print(id(a))
print(id(b))
print(id(c))
print(id(d))
# Out:
# 1918623968208
# 140710734268984
# 1918623831504
# 1918623831504

# %%
print(a==c)
# Out:
# True

# %%
print(c is d)
# Out:
# True

# %%
print(a is b)
# Out:
# False

# %%
print(c is not d)
# Out:
# False

# %% [markdown]
# ### Ternary or conditional operator

# %%
### syntax

### Value_if_true if condition else value_if_false

# %%
age = 19

if age>=18:  # 19>=18
    print("Major")
else:
    print("Minor")
# Out:
# Major

# %%
age = 16

result = "Major" if age>=18 else "Minor"
print(result)
# Out:
# Minor
