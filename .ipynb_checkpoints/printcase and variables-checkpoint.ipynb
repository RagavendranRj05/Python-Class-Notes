# %%
print('Hi')
# Out:
# Hi

# %%
print('55')
# Out:
# 55

# %%
print("10-12-2025")
# Out:
# 10-12-2025

# %% [markdown]
# ## , Seperator
# ## ( open parenthesis and ) close parenthesis
#
# ## sep - keyword or argument

# %%
print("apple","mango","banana","kiwi","ornage",sep="++")
# Out:
# apple++mango++banana++kiwi++ornage

# %%
print("hello","hello",end=",Good morning ")
print("Bhavani")
print("lein")
# Out:
# hello hello,Good morning Bhavani
# lein

# %%
print("bhavani","lein","Riswan","Bhavadharani","vignesh",sep="..",end=", Hi students ")
print("welcome")
# Out:
# bhavani..lein..Riswan..Bhavadharani..vignesh, Hi students welcome

# %%
# hi..hi..hi
print("hi","hi",sep="..",end="..hi")
# Out:
# hi..hi..hi

# %%
print("hi","hi",sep="..",end="..")
print("hi")
# Out:
# hi..hi..hi

# %%
print("hi","hi","hi",sep="..")
# Out:
# hi..hi..hi

# %%
print("hi","hi",sep="..hi..")
# Out:
# hi..hi..hi

# %%
print(6*2)
# Out:
# 12

# %%
# print("apple","mango","banana","kiwi","ornage",sep="++")
# Out:
# apple++mango++banana++kiwi++ornage
# '\nprint("hello","hello",end=",Good morning ")\nprint("Bhavani")\nprint("lein")\n'

# %%
print('""')
# Out:
# ""

# %%
print("''")
# Out:
# ''

# %%
print("""")
# Out:
#   Cell In[61], line 1
#     print("""")
#           ^
# SyntaxError: incomplete input

# %% [markdown]
# #### title

# %%
print(8-5)
# Out:
# 3

# %% [markdown]
# ## Variables are containers for storing data values.

# %%
a = 5    # a is a variable name or container or identifier  and  5 is value and = is a assingment operator is used to assing the value 
          # to a variable
print(a)
# Out:
# 5

# %%
b = 10
print(b)
# Out:
# 10

# %%
c = "oil"
print(c)
# Out:
# oil

# %% [markdown]
# # Rules of variables or identifiers

# %% [markdown]
# ## 1. variables cannot be start with a number
# ## 2. variables cannot be start with a python keyword
# ## 3. variables must be in case sensitive
# ## 4. vaiables must be start wiht a alphabet or underscore

# %%
5 = 5 # rule 1
# Out:
#   Cell In[72], line 1
#     5 = 5
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
True = 5 # rule 2
# Out:
#   Cell In[77], line 1
#     True = 5 # rule 2
#     ^
# SyntaxError: cannot assign to True

# %%
smallNum = 1 # rule 3
print(smallNum)
# Out:
# 1

# %%
_ = 5 # rule 4
print(_)
# Out:
# 5

# %%
a = 8    #rule 4
print(a)
# Out:
# 8

# %%
a5 = 0
print(a5)
# Out:
# 0

# %%
b-= 6
print(b-)
# Out:
#   Cell In[89], line 2
#     print(b-)
#             ^
# SyntaxError: invalid syntax
